# %% [markdown]
# # Webscraping with Python Tutorial
# For the 2024 CSHL Advanced Sequencing Technologies & Bioinformatics Analysis course

# %% [markdown]
# ## Using the Requests library

# %%
import requests

# %% [markdown]
# ### Retrieve content with .get
# Let's retrieve all of the [CSHL meetings](https://meetings.cshl.edu/meetings) programatically using a web scraper.

# %%
offerings_page_url = "https://meetings.cshl.edu/meetings"
cshl_meetings_response = requests.get(offerings_page_url)

# %% [markdown]
# ### Check request status with .status_code
# A good first check is to see if your response was successful (e.g. returned a 200 (OK) [status code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)).
#
# Other popular codes include:
# - 302 (Found)
# - 404 (Not Found)
# - 401 (Unauthorized)
# - 418 (I'm a Teapot)

# %%
cshl_meetings_response.status_code
# Out:
# 200

# %% [markdown]
# _Try it yourself:_ Modify the below code to grab content from another site. Was it successful? Why or why not?

# %%
# Get the content
test_page_url = ?
test_page_response = requests.? ( ? )

# Check the status code
test_page_response. ?

# %% [markdown]
# ### View response content
# Text content of responses can be viewed using `.text`, and json-formatted responses can be viewed using `.json`

# %%
cshl_meetings_response.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n\r\n<html lang="en">\r\n\r\n<head>\r\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\r\n    <script async src="https://www.googletagmanager.com/gtag/js?id=UA-30723914-1"></script>\r\n    <script>\r\n        window.dataLayer = window.dataLayer || [];\r\n        function gtag(){dataLayer.push(arguments);}\r\n        gtag(\'js\', new Date());\r\n\r\n        gtag(\'config\', \'UA-30723914-1\');\r\n        gtag(\'config\', \'G-85036B76HX\');\r\n    </script>\r\n    \r\n    <title>\r\n\tMeetings on Cancer, Cells, Genomics, Neuroscience, Genetics and Immunology\r\n</title><meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1" /><meta name="description" content="Meetings and Conferences on Cancer, Cells, Genomics, Neuroscience, Genetics and Immunology" /><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" /><link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/jquery.jssocials/1.4.0/jssocials.css" /><link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/jquery.jssocials/1.4.0/jssocials-theme-classic.css" /><link rel="shortcut icon" href="https://meetings.cshl.edu/favi.ico" type="image/x-icon" /><link rel="icon" href="https://meetings.cshl.edu/favi.ico" type="image/ico" /><link rel="manifest" href="https://meetings.cshl.edu/manifest.txt" /><link rel="canonical" href="https://meetings.cshl.edu/meetings" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:description" content="Cold Spring Harbor Laboratory Meetings &amp; Courses -- a private, non-profit institution with research programs in cancer, neuroscience, plant biology, genomics, bioinformatics." />\r\n    <meta name="twitter:title" content=\'\' />\r\n    <meta name="twitter:site" content="@cshlmeetings" /><meta name="twitter:url" content="https://meetings.cshl.edu" /><meta name="twitter:image" content="https://meetings.cshl.edu/images/twitter-link.jpg" /><meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="viewport" content="width=device-width" />\r\n\r\n    <!-- THIRD PARTY FILES -->\r\n    <link rel="shortcut icon" href="favicon.ico" /><link rel="stylesheet" href="css/bootstrap.min.css" /><link href="css/iconicons.min.css" rel="stylesheet" /><link href="fonts/font-awesome.min.css" rel="stylesheet" /><link href="fonts/icomoon/styles.css" rel="stylesheet" type="text/css" /><link href="css/animate.css" rel="stylesheet" />\r\n    <!-- INTERNAL CSS-->\r\n    <link href="css/styles.min.css" rel="stylesheet" /><link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400" rel="stylesheet" /><link href="https://fonts.googleapis.com/css?family=Noto+Serif" rel="stylesheet" /><link href="css/temp.min.css" rel="stylesheet" />\r\n    <style>\r\n        @media screen and (-ms-high-contrast: active), (-ms-high-contrast: none) {\r\n            nav.navbar.navbar-default.navbar-static-top li a {\r\n                font-size: 13px;\r\n                padding: 16px 10px 17px 10px;\r\n            }\r\n            .container-fluid:after,\r\n        .row:after,\r\n        .navbar:after,\r\n        .navbar-header:after {\r\n            clear: none;\r\n        }\r\n        }\r\n        </style>\r\n        <style>\r\n        .row:before, .row:after {display: none !important;}\r\n        </style>\r\n\r\n        <style>\r\n            .sci-type-btn {\r\n                cursor: pointer;\r\n                margin: 10px;\r\n                border-radius: 10px;\r\n                text-decoration: none;\r\n                padding: 6px;\r\n                font-size: 16px;\r\n                transition: .3s;\r\n                -webkit-transition: .3s;\r\n                -moz-transition: .3s;\r\n                -o-transition: .3s;\r\n                display: inline-block;\r\n                width:100px;\r\n                text-align: center;\r\n                background-color: white;\r\n           ...

# %% [markdown]
# Wow, that's a lot of HTML under the hood. We will need a way to parse through this.

# %% [markdown]
# ### Requesting JSON content from web APIs
# Another common use of the requests library is to retrieve JSON content from web APIs. Let's take a look at the [LitVar search API]():

# %%
variant_id = 'rs113488022'
url = f'https://www.ncbi.nlm.nih.gov/research/litvar2-api/variant/get/litvar@{variant_id}%23%23'
litvar_response = requests.get(url)

# %%
litvar_response.status_code
# Out:
# 200

# %%
litvar_response.json()
# Out:
# {'_id': 'litvar@rs113488022##',
#  'concept': 'variant',
#  'rsid': 'rs113488022',
#  'clingen_ids': ['CA281998', 'CA123643', 'CA16602736'],
#  'gene': ['BRAF'],
#  'name': 'p.V600E',
#  'hgvs': 'p.V600E',
#  'flag_gene_variant': False,
#  'flag_clingen_variant': False,
#  'flag_rsid_variant': True,
#  'data_species': ['Homo sapiens'],
#  'data_snp_id': ['113488022'],
#  'data_tax_id': ['9606'],
#  'data_allele': ['N'],
#  'data_snp_class': ['snv'],
#  'data_chromosome_base_position': ['7:140753336'],
#  'data_clinical_significance': ['other',
#   'drug-response',
#   'pathogenic',
#   'likely-pathogenic']}

# %% [markdown]
# ## Introduction to Web Scraping using `beautifulsoup4`

# %% [markdown]
# Let's go back to our scraping of the CSHL meetings website. We had a lot of content there that looked difficult to parse. Let's see how the beautifulsoup library can help us improve on this.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### Making the Soup
# BeautifulSoup can parse XML as well as HTML, so we need to specify what parser we want to use when we pass it content.

# %%
cshl_meetings_soup = BeautifulSoup(cshl_meetings_response.text, "html.parser")

# %%
cshl_meetings_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-30723914-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'UA-30723914-1');
#         gtag('config', 'G-85036B76HX');
#     </script>
# <title>
# 	Meetings on Cancer, Cells, Genomics, Neuroscience, Genetics and Immunology
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="Meetings and Conferences on Cancer, Cells, Genomics, Neuroscience, Genetics and Immunology" name="description"/><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/><link href="https://cdn.jsdelivr.net/jquery.jssocials/1.4.0/jssocials.css" rel="stylesheet" type="text/css"/><link href="https://cdn.jsdelivr.net/jquery.jssocials/1.4.0/jssocials-theme-classic.css" rel="stylesheet" type="text/css"/><link href="https://meetings.cshl.edu/favi.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://meetings.cshl.edu/favi.ico" rel="icon" type="image/ico"/><link href="https://meetings.cshl.edu/manifest.txt" rel="manifest"/><link href="https://meetings.cshl.edu/meetings" rel="canonical"/><meta content="summary_large_image" name="twitter:card"/><meta content="Cold Spring Harbor Laboratory Meetings &amp; Courses -- a private, non-profit institution with research programs in cancer, neuroscience, plant biology, genomics, bioinformatics." name="twitter:description"/>
# <meta content="" name="twitter:title"/>
# <meta content="@cshlmeetings" name="twitter:site"/><meta content="https://meetings.cshl.edu" name="twitter:url"/><meta content="https://meetings.cshl.edu/images/twitter-link.jpg" name="twitter:image"/><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width" name="viewport"/>
# <!-- THIRD PARTY FILES -->
# <link href="favicon.ico" rel="shortcut icon"/><link href="css/bootstrap.min.css" rel="stylesheet"/><link href="css/iconicons.min.css" rel="stylesheet"/><link href="fonts/font-awesome.min.css" rel="stylesheet"/><link href="fonts/icomoon/styles.css" rel="stylesheet" type="text/css"/><link href="css/animate.css" rel="stylesheet"/>
# <!-- INTERNAL CSS-->
# <link href="css/styles.min.css" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Noto+Serif" rel="stylesheet"/><link href="css/temp.min.css" rel="stylesheet"/>
# <style>
#         @media screen and (-ms-high-contrast: active), (-ms-high-contrast: none) {
#             nav.navbar.navbar-default.navbar-static-top li a {
#                 font-size: 13px;
#                 padding: 16px 10px 17px 10px;
#             }
#             .container-fluid:after,
#         .row:after,
#         .navbar:after,
#         .navbar-header:after {
#             clear: none;
#         }
#         }
#         </style>
# <style>
#         .row:before, .row:after {display: none !important;}
#         </style>
# <style>
#             .sci-type-btn {
#                 cursor: pointer;
#                 margin: 10px;
#                 border-radius: 10px;
#                 text-decoration: none;
#                 padding: 6px;
#                 font-size: 16px;
#                 transition: .3s;
#                 -webkit-transition: .3s;
#                 -moz-transition: .3s;
#                 -o-transition: .3s;
#                 display: inline-block;
#                 width:100px;
#                 text-align: center;
#                 background-color: white;
#                 /*white-space: pre-wrap;*/
#             }
#
#             .sci-type-darkgrey {
#                 color:#444;
#                 border: 2px #444 solid;
#             }
#
#             .sci-type-darkgrey:hover {
#                 background-color: #444;
#                     color: #fff;
#             }
#
#             .sci-type-blue {
#                 color: #55acee;
#                 border: 2px #55acee solid;
#             }
#
#
#             .sci-type-blue:hover {
#                     background-color: #55acee;
#                     color: #fff;
#             }
#
#
#             .sci-type-bluetittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #55acee;
#             }
#
#             .sci-type-green {
#                 color: #2ecc71;
#                 border: 2px #2ecc71 solid;
#             }
#
#                 .sci-type-green:hover {
#                     color: #fff;
#                     background-color: #2ecc71;
#                 }
#
#             .sci-type-greentittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #2ecc71;
#             }
#
#             .sci-type-orange {
#                 color: #e67e22;
#                 border: 2px #e67e22 solid;
#             }
#
#             .sci-type-orange:hover {
#                     color: #fff;
#                     background-color: #e67e22;
#                 }
#
#             .sci-type-orangetittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #e67e22;
#             }
#
#             .sci-type-yellow {
#                 color: #f1c40f;
#                 border: 2px #f1c40f solid;
#             }
#
#             .sci-type-yellow:hover {
#                     color: #fff;
#                     background-color: #f1c40f;
#                 }
#
#             .sci-type-yellowtittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #f1c40f;
#             }
#
#
#             .sci-type-brown {
#                 color: #b09470;
#                 border: 2px #b09470 solid;
#             }
#
#                 .sci-type-brown:hover {
#                     color: #fff;
#                     background-color: #b09470;
#                 }
#
#             .sci-type-brown a {
#
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #b09470;
#             }
#
#             .sci-type-browntittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #b09470;
#             }
#
#
#
#             .sci-type-darkred {
#                 color: #b30000;
#                 border: 2px #b30000 solid;
#             }
#
#                 .sci-type-darkred:hover {
#                     color: #fff;
#                     background-color: #b30000;
#                 }
#
#             .sci-type-darkred a {
#
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color:#b30000;
#             }
#
#
#             .sci-type-darkredtittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #b30000;
#             }
#
#
#             .sci-type-white {
#                 color: #000;
#                 border: 2px #000 solid;
#             }
#
#                 .sci-type-white:hover {
#                     color: #000;
#                     background-color: #FFF;
#                 }
#
#             .sci-type-whitetittle a {
#                 font-size: 18px;
#                 font-weight: bold;
#                 line-height: 135%;
#                 color: #12007c;
#             }
#             /* .science-type-blue:hover {
#                 color: #fff;
#                 background-color: #f1c40f;
#             }
#             .science-type-blue {
#                 color: #f1c40f;
#                 border: 2px #f1c40f solid;
#             }
#             .science-type-blue:hover {
#                 color: #fff;
#                 background-color: #f1c40f;
#             }
#             .science-type-blue {
#                 color: #f1c40f;
#                 border: 2px #f1c40f solid;
#             }
#             .science-type-button:hover {
#                 color:white;
#             } */
#
#             tr.science-type-row {
#                 border-top: 4px solid white;
#                 border-bottom: 4px solid white;
#             }
#
#             button:focus {
#                 outline: 0;
#             }
#         </style>
# </head>
# <body style="background: white">
# <form action="./meetingshome.aspx" id="form1" method="post" name="form1">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="28258BD8"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# <nav class="main-navigation navbar navbar-default navbar-stat-top" id="site-navigation" role="navigation">
# <div class="container-fluid" id="new-primary-wrapper" style="padding:0 !important;">
# <div id="new-primary-background"></div>
# <div class="navbar-header" style="position:relative;">
# <a class="navbar-brand" href="https://www.cshl.edu/">
# <!--  Cold Spring Harbor Laboratory -->
# </a>
# </div>
# <div class="menu-container">
# <div class="menu" style="padding:0 !important">
# <a class="menu-mobile" href="#"></a>
# <ul class="menu" id="primary-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28878"><a href="https://www.cshl.edu/about-us/">About Us</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28879"><a href="https://www.cshl.edu/public-events/">Events</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28880"><a href="https://www.cshl.edu/news-stand/">Newsstand</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28881"><a href="https://www.cshl.edu/partner-with-us/">Partner With Us</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28882"><a href="https://www.cshl.edu/about-us/careers/">Careers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28883"><a href="https://www.cshl.edu/giving/">Giving</a>
# </li>
# </ul>
# <a class="menu-mobile" href="#"></a>
# <ul class="menu" id="primary-menu-right">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28870"><a href="https://www.cshl.edu/education/">Education Programs</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28871"><a href="https://www.cshl.edu/research/faculty-staff/">Faculty</a></li>
# </ul>
# <a class="menu-mobile" href="#"></a>
# <ul class="menu" id="divisions-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28872"><a href="https://www.cshl.edu/research/">Research</a>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28873"><a href="https://www.cshl.edu/education/banbury/">Banbury Center</a>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-28874"><a href="https://cshlpress.com/">CSHL Press</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-28875"><a href="https://dnalc.org/">DNA Learning Center</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-28876" style="font-weight:bold;"><a href="https://meetings.cshl.edu/">Meetings &amp; Courses</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28877"><a href="https://www.cshl.edu/education/phd-program/">Ph.D. Program</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# <!-- Slider -->
# <div class="heading carousel-transparent-gray-bg d-block d-sm-none">
# <!-- Required header field -->
# <h1 style="margin-bottom: 2px; padding-bottom: 2px; font-family: 'Source Sans Pro', sans-serif !important; font-size: 20px">Meetings &amp; Courses Program</h1>
# <div style="
#    font-size: 16px;
#    margin-bottom: 2px;
#    padding-bottom: 2px;
#    font-family: 'Source Sans Pro', sans-serif !important;
#    font-size: 16px;
#    margin-left: 10px;
# ">Crossroads of Biology</div>
# </div>
# <div class="carousel slide carousel-fade mb-1" data-interval="6000" data-ride="carousel" id="carousel">
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carousel"></li>
# <li data-slide-to="1" data-target="#carousel"></li>
# <li data-slide-to="2" data-target="#carousel"></li>
# </ol>
# <div class="carousel-inner" role="listbox">
# <div class="carousel-item active" role="option">
# <div class="heading carousel-transparent-gray-bg d-none d-sm-block">
# <!-- Required header field -->
# <h1 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Meetings &amp; Courses Program</h1>
# <h4 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Crossroads of Biology</h4>
# </div>
# <picture>
# <source media="(min-width: 1400px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_1.jpg"/>
# <source media="(min-width: 769px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_1.jpg"/>
# <source media="(min-width: 577px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small1.jpg"/>
# <img alt="responsive image" class="d-block img-fluid" src="https://meetings.cshl.edu/redesign/imgs/home_image_1.jpg" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small1.jpg"/>
# </picture>
# </div>
# <!-- /.carousel-item -->
# <div class="carousel-item" role="option">
# <div class="heading carousel-transparent-gray-bg d-none d-sm-block">
# <!-- Required header field -->
# <h1 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Meetings &amp; Courses Program</h1>
# <h4 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Crossroads of Biology</h4>
# </div>
# <picture>
# <source media="(min-width: 1400px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_2.jpg"/>
# <source media="(min-width: 769px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_2.jpg"/>
# <source media="(min-width: 577px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small2.jpg"/>
# <img alt="responsive image" class="d-block img-fluid" src="https://meetings.cshl.edu/redesign/imgs/home_image_2.jpg" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small2.jpg"/>
# </picture>
# </div>
# <!-- /.carousel-item -->
# <div class="carousel-item" role="option">
# <div class="heading carousel-transparent-gray-bg d-none d-sm-block">
# <!-- Required header field -->
# <h1 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Meetings &amp; Courses Program</h1>
# <h4 style="font-family: 'Source Sans Pro', sans-serif !important; font-weight: 300 !important">Crossroads of Biology</h4>
# </div>
# <picture>
# <source media="(min-width: 1400px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_3.jpg"/>
# <source media="(min-width: 769px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_3.jpg"/>
# <source media="(min-width: 577px)" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small3.jpg"/>
# <img alt="responsive image" class="lazyload d-block img-fluid" data-src="https://meetings.cshl.edu/redesign/imgs/home_image_3.jpg" srcset="https://meetings.cshl.edu/redesign/imgs/home_image_small3.jpg"/>
# </picture>
# </div>
# <!-- /.carousel-item -->
# </div>
# <!-- /.carousel-inner -->
# <a class="carousel-control-prev" data-slide="prev" href="#carousel" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#carousel" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# <!-- Slider -->
# <div class="overlay" id="overlay">
# <nav class="overlay-menu">
# <ul>
# <li><a href="https://meetings.cshl.edu/">Home</a></li>
# <li><a href="https://meetings.cshl.edu/meetingshome.aspx">Meetings</a></li>
# <li><a href="https://meetings.cshl.edu/meetings">Courses</a></li>
# <li id="close-overlay-toggle"><a href="#"><i aria-hidden="true" class="fa fa-window-close"></i></a></li>
# </ul>
# </nav>
# </div>
# <!-- Floating Menu -->
# <div class="container">
# <div class="row py-4">
# <div class="col-md-12 align-content-center">
# <ul class="nav nav-pills nav-fill navtop d-flex" id="sticker" style="z-index: 9999!important;">
# <li class="nav-item px-md-1 px-sm-0">
# <a class="nav-link active cshl-blue cshl-shadow trans meet-nav" href="https://meetings.cshl.edu/" style="border-radius: 7px !important; border: 2px solid white;">Home</a>
# </li>
# <li class="nav-item px-md-1 px-sm-0">
# <a class="nav-link active cshl-blue cshl-shadow trans meet-nav" href="https://meetings.cshl.edu/meetings" style="border-radius: 7px !important; border: 2px solid white;">Meetings</a>
# </li>
# <li class="nav-item px-md-1 px-sm-0">
# <a class="nav-link active cshl-blue cshl-shadow trans meet-nav" href="https://meetings.cshl.edu/courses" style="border-radius: 7px !important; border: 2px solid white;">Courses</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- End Floating Menu -->
# <div class="container-fluid pt-1 pb-1">
# <!-- Tagline -->
# <div class="row">
# <div class="col">
# <h2 class="text-center text-center" style="color: #444!important; font-family: 'Source Sans Pro',sans-serif; padding-top: 15px;">Meetings &amp; Conferences</h2>
# </div>
# </div>
# </div>
# <!-- Science Type Menu -->
# <div class="container">
# <div class="row py-2">
# <div class="col text-center">
# <button class="sci-type-btn sci-type-darkgrey m-1" data-sort="A" id="sci-button-all" type="button">All</button>
# <button class="sci-type-btn sci-type-blue m-1" data-sort="C" id="sci-button-cancer" type="button">Cancer</button>
# <button class="sci-type-btn sci-type-green m-1" data-sort="B" id="sci-button-cell" type="button">Cell</button>
# <button class="sci-type-btn sci-type-orange m-1" data-sort="O" id="sci-button-omics" type="button">'Omics</button>
# <button class="sci-type-btn sci-type-yellow m-1" data-sort="N" id="sci-button-neuro" type="button">Neuro</button>
# <button class="sci-type-btn sci-type-brown m-1" data-sort="G" id="sci-button-genetics" type="button">Genetics</button>
# <button class="sci-type-btn sci-type-darkred m-1" data-sort="I" id="sci-button-immune" type="button">Immun</button>
# </div>
# </div>
# </div>
# <!-- End Science Type Menu -->
# <section class="container" id="copybox" style="padding: 20px !important; box-shadow: 0 1px 2px 0 rgba(0, 0, 0, 0.4);">
# <div class="container-fluid">
# <div class="row justify-content-center">
# <div class="col-xs-10 col-sm-10 col-md-12">
# <table border="0" cellpadding="0" cellspacing="0" class="footable" id="tblCustomers" style="font-family:'Source Sans Pro', sans-serif">
# <thead style="font-family:'Source Sans Pro', sans-serif !important">
# <div class="container-fluid">
# </div>
# </thead>
# <thead>
# <tr>
# <th data-class="expand">Meeting Name
#                                             </th>
# <th data-hide="phone" style="display: table-cell;">Meeting Dates
#                                             </th>
# <th data-hide="phone" style="display: table-cell;">Abstracts Due
#                                             </th>
# </tr>
# </thead>
# <tbody>
# <tr class="science-type-row" data-sci="N" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl01$meetings','')" id="repeater_meetings_ctl01_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Neurodegenerative Diseases: Biology &amp; Therapeutics</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Dec 4 - Sat Dec 7 2024
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Sep 13 2024
#
#                                                 <input id="repeater_meetings_ctl01_repeaterKey" name="repeater_meetings$ctl01$repeaterKey" type="hidden" value="N"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="N" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl02$meetings','')" id="repeater_meetings_ctl02_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Development &amp; 3D Modeling of the Human Brain</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon Dec 9 - Thu Dec 12 2024
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon Oct 7 2024
#
#                                                 <input id="repeater_meetings_ctl02_repeaterKey" name="repeater_meetings$ctl02$repeaterKey" type="hidden" value="N"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="O" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl03$meetings','')" id="repeater_meetings_ctl03_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Probabilistic Modeling in Genomics</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Mar 5 - Sat Mar 8 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 10 2025
#
#                                                 <input id="repeater_meetings_ctl03_repeaterKey" name="repeater_meetings$ctl03$repeaterKey" type="hidden" value="O"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BO" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl04$meetings','')" id="repeater_meetings_ctl04_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Network Biology</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Mar 11 - Sat Mar 15 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 10 2025
#
#                                                 <input id="repeater_meetings_ctl04_repeaterKey" name="repeater_meetings$ctl04$repeaterKey" type="hidden" value="BO"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BCGO" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl05$meetings','')" id="repeater_meetings_ctl05_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Nucleic Acid Therapies</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Mar 19 - Sat Mar 22 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 17 2025
#
#                                                 <input id="repeater_meetings_ctl05_repeaterKey" name="repeater_meetings$ctl05$repeaterKey" type="hidden" value="BCGO"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BCONI" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl06$meetings','')" id="repeater_meetings_ctl06_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Cancer Genetics: History &amp; Consequences</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Mar 26 - Sat Mar 29 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 31 2025
#
#                                                 <input id="repeater_meetings_ctl06_repeaterKey" name="repeater_meetings$ctl06$repeaterKey" type="hidden" value="BCONI"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BCG" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl07$meetings','')" id="repeater_meetings_ctl07_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Ubiquitins, Autophagy &amp; Disease</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Apr 1 - Sat Apr 5 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 17 2025
#
#                                                 <input id="repeater_meetings_ctl07_repeaterKey" name="repeater_meetings$ctl07$repeaterKey" type="hidden" value="BCG"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="N" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl08$meetings','')" id="repeater_meetings_ctl08_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Brain Barriers</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Apr 8 - Sat Apr 12 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 24 2025
#
#                                                 <input id="repeater_meetings_ctl08_repeaterKey" name="repeater_meetings$ctl08$repeaterKey" type="hidden" value="N"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="OI" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl09$meetings','')" id="repeater_meetings_ctl09_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Systems Immunology</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Apr 22 - Sat Apr 26 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jan 31 2025
#
#                                                 <input id="repeater_meetings_ctl09_repeaterKey" name="repeater_meetings$ctl09$repeaterKey" type="hidden" value="OI"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="GO" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl10$meetings','')" id="repeater_meetings_ctl10_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Telomeres &amp; Telomerase</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Apr 29 - Sat May 3 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Feb 7 2025
#
#                                                 <input id="repeater_meetings_ctl10_repeaterKey" name="repeater_meetings$ctl10$repeaterKey" type="hidden" value="GO"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="CO" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl11$meetings','')" id="repeater_meetings_ctl11_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Biology of Genomes</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue May 6 - Sat May 10 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Feb 14 2025
#
#                                                 <input id="repeater_meetings_ctl11_repeaterKey" name="repeater_meetings$ctl11$repeaterKey" type="hidden" value="CO"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl12$meetings','')" id="repeater_meetings_ctl12_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Mechanisms of Metabolic Signaling</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue May 13 - Sat May 17 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Feb 21 2025
#
#                                                 <input id="repeater_meetings_ctl12_repeaterKey" name="repeater_meetings$ctl12$repeaterKey" type="hidden" value="BC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="I" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl13$meetings','')" id="repeater_meetings_ctl13_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Retroviruses</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon May 19 - Sat May 24 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Feb 28 2025
#
#                                                 <input id="repeater_meetings_ctl13_repeaterKey" name="repeater_meetings$ctl13$repeaterKey" type="hidden" value="I"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BCG" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl14$meetings','')" id="repeater_meetings_ctl14_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">89th Symposium: Senescence &amp; Aging</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed May 28 - Sun Jun 1 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Mar 7 2025
#
#                                                 <input id="repeater_meetings_ctl14_repeaterKey" name="repeater_meetings$ctl14$repeaterKey" type="hidden" value="BCG"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="C" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl15$meetings','')" id="repeater_meetings_ctl15_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Advances in Brain Tumor Research &amp; Therapy</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Thu Jul 17 - Sun Jul 20 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Apr 25 2025
#
#                                                 <input id="repeater_meetings_ctl15_repeaterKey" name="repeater_meetings$ctl15$repeaterKey" type="hidden" value="C"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="GOC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl16$meetings','')" id="repeater_meetings_ctl16_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Genome Engineering: CRISPR Frontiers</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Aug 12 - Sat Aug 16 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri May 23 2025
#
#                                                 <input id="repeater_meetings_ctl16_repeaterKey" name="repeater_meetings$ctl16$repeaterKey" type="hidden" value="GOC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl17$meetings','')" id="repeater_meetings_ctl17_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Eukaryotic mRNA Processing</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Aug 19 - Sat Aug 23 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri May 30 2025
#
#                                                 <input id="repeater_meetings_ctl17_repeaterKey" name="repeater_meetings$ctl17$repeaterKey" type="hidden" value="BC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl18$meetings','')" id="repeater_meetings_ctl18_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Mechanisms of Eukaryotic Transcription</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Aug 26 - Sat Aug 30 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jun 6 2025
#
#                                                 <input id="repeater_meetings_ctl18_repeaterKey" name="repeater_meetings$ctl18$repeaterKey" type="hidden" value="BC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl19$meetings','')" id="repeater_meetings_ctl19_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Eukaryotic DNA Replication &amp; Genome Maintenance</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Sep 2 - Sat Sep 6 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jun 13 2025
#
#                                                 <input id="repeater_meetings_ctl19_repeaterKey" name="repeater_meetings$ctl19$repeaterKey" type="hidden" value="BC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="I" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl20$meetings','')" id="repeater_meetings_ctl20_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Microbial Pathogenesis &amp; Host Response</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon Sep 8 - Fri Sep 12 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jun 20 2025
#
#                                                 <input id="repeater_meetings_ctl20_repeaterKey" name="repeater_meetings$ctl20$repeaterKey" type="hidden" value="I"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="C" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl21$meetings','')" id="repeater_meetings_ctl21_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Biology of Cancer: Microenvironment &amp; Metastasis</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Sep 16 - Sat Sep 20 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Jun 27 2025
#
#                                                 <input id="repeater_meetings_ctl21_repeaterKey" name="repeater_meetings$ctl21$repeaterKey" type="hidden" value="C"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="B" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl22$meetings','')" id="repeater_meetings_ctl22_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Cell Fate Conversions</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Sep 24 - Sat Sep 27 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon Jul 7 2025
#
#                                                 <input id="repeater_meetings_ctl22_repeaterKey" name="repeater_meetings$ctl22$repeaterKey" type="hidden" value="B"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="N" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl23$meetings','')" id="repeater_meetings_ctl23_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Neurobiology of Drosophila</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Tue Oct 7 - Sat Oct 11 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Mon Jul 21 2025
#
#                                                 <input id="repeater_meetings_ctl23_repeaterKey" name="repeater_meetings$ctl23$repeaterKey" type="hidden" value="N"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl24$meetings','')" id="repeater_meetings_ctl24_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Genome Informatics</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Nov 5 - Sat Nov 8 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Aug 22 2025
#
#                                                 <input id="repeater_meetings_ctl24_repeaterKey" name="repeater_meetings$ctl24$repeaterKey" type="hidden"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="BONC" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl25$meetings','')" id="repeater_meetings_ctl25_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Single Cell Analyses</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Nov 12 - Sat Nov 15 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Aug 29 2025
#
#                                                 <input id="repeater_meetings_ctl25_repeaterKey" name="repeater_meetings$ctl25$repeaterKey" type="hidden" value="BONC"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="N" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl26$meetings','')" id="repeater_meetings_ctl26_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Zebrafish Neurobiology</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Nov 19 - Sat Nov 22 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Sep 5 2025
#
#                                                 <input id="repeater_meetings_ctl26_repeaterKey" name="repeater_meetings$ctl26$repeaterKey" type="hidden" value="N"/>
# </td>
# </tr>
# </tbody>
# <tbody>
# <tr class="science-type-row" data-sci="GO" style="border-left:4px solid white; font-family:'Source Sans Pro', sans-serif !important">
# <td data-class="expand">
# <a href="javascript:__doPostBack('repeater_meetings$ctl27$meetings','')" id="repeater_meetings_ctl27_meetings" style="display:inline-block;font-family:'Source Sans Pro', sans-serif !important"><font color="#6588A8">Plant Genomes, Systems Biology &amp; Engineering</font></a>
# </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Wed Dec 3 - Sat Dec 6 2025
#
#                                             </td>
# <td data-hide="phone" style="display: table-cell; font-family:'Source Sans Pro', sans-serif !important">
#                                                 Fri Sep 12 2025
#
#                                                 <input id="repeater_meetings_ctl27_repeaterKey" name="repeater_meetings$ctl27$repeaterKey" type="hidden" value="GO"/>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </section>
# ...
# <a href="https://currentexchange.cshl.edu/" rel="noopener" target="_blank">Current Exchange <span class="fa fa-external-link"></span></a><br/>
# <a href="https://www.twitter.com/cshlmeetings" rel="noopener" target="_blank" title="follow us on Twitter">Twitter CSHL Meetings <span class="fa fa-twitter"></span></a><br/>
# <a href="https://www.twitter.com/cshlcourses" rel="noopener" target="_blank" title="follow us on Twitter">Twitter CSHL Courses <span class="fa fa-twitter"></span></a><br/>
# <a href="https://www.instagram.com/cshlmeetings" rel="noopener" target="_blank" title="view our photos on Instagram">Instagram <span class="fa fa-instagram"></span></a><br/>
# </p>
# </div>
# <!-- /column -->
# <!-- /column -->
# <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# <h4 class="section-h4">Contact Us</h4>
# <p>
#                                   Meetings &amp; Courses Program <br/>
#                                   Cold Spring Harbor Laboratory <br/>
#                                   One Bungtown Road, Cold Spring Harbor, NY 11724 <br/>
# <a href="tel:1-516-367-8346"><span class="fa fa-lg fa-phone-square"></span> (516) 367-8346</a><br/>
# <a href="mailto:meetings@cshl.edu"><span class="fa fa-lg fa-envelope"></span> meetings@cshl.edu</a>
# </p>
# </div>
# <!-- /column -->
# </div>
# <!--row-->
# </div>
# <!--col-->
# </div>
# <!--gradient row-->
# </div>
# <br/>
# </section>
# <div class="row">
# <div class="offset-lg-1 col-lg-11 col-xs-12">
# <div class="row">
# <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12 bottom-footer-column">
# <h3 class="footer-contact-h3">Main Menu</h3>
# <ul class="menu" id="footer-column-1"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29002"><a href="https://www.cshl.edu/about-us/">About</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29003"><a href="https://www.cshl.edu/public-events/">Events</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29004"><a href="https://www.cshl.edu/news-stand/">Newsstand</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29005"><a href="https://www.cshl.edu/partner-with-us/">Partner With Us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29006"><a href="https://www.cshl.edu/about-us/careers/">Careers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29007"><a href="https://www.cshl.edu/giving/">Giving</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-page-ancestor menu-item-29008"><a href="https://www.cshl.edu/education/">Educational Programs</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29009"><a href="https://www.cshl.edu/research/faculty-staff/">Faculty</a></li>
# </ul>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12 bottom-footer-column">
# <h3 class="footer-contact-h3">Divisions</h3>
# <ul class="menu" id="footer-column-2"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29010"><a href="https://www.cshl.edu/research/">Research</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-253 current_page_item menu-item-29011"><a href="https://www.cshl.edu/education/banbury/">Banbury Center</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29012"><a href="https://www.cshl.edu/education/cshl-press/">CSHL Press</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29013"><a href="https://www.cshl.edu/education/dna-learning-center/">DNA Learning Center</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29014"><a href="https://meetings.cshl.edu/" style="font-weight: bold;">Meetings &amp; Courses Program</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29015"><a href="https://www.cshl.edu/education/phd-program/">Ph.D. Program</a></li>
# </ul> </div>
# <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12 bottom-footer-column">
# <h3 class="footer-contact-h3">Resources</h3>
# <ul class="menu" id="footer-column-3"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-29016"><a href="https://www.cshl.edu/education/library-archives/">Library &amp; Archives</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-29017"><a href="https://www.cshl.edu/partner-with-us/preprints/">Preprints</a></li>
# </ul> </div>
# <div class="col-lg-3 col-md-3 col-sm-3 col-xs-12 bottom-footer-column" id="footer-contact-column">
# <!-- need to take the pull-right class out of this div in functions.php line 144 -->
# <div id="custom_html-3"><div class="textwidget custom-html-widget"> <h3 class="footer-contact-h3">Contact</h3>
# <p class="contact"><a href="tel:1-516-367-8800"><span class="fa fa-lg fa-phone-square"></span> (516) 367-8800</a><br/>
# <a href="mailto:info@cshl.edu"><span class="fa fa-lg fa-envelope"></span> info@cshl.edu</a><br/>
# <a href="https://www.cshl.edu/about-us/directions/"><span class="fa fa-lg fa-map"></span> Maps &amp; Directions</a></p>
# <p><a class="btn btn-learn-more-ag-green" href="https://give.cshl.edu/"><span class="fa fa-lg fa-gift"></span> Donate Now</a></p>
# <p><a class="btn btn-learn-more-ag-green" href="https://www.cshl.edu/news-stand/newsletter/"><span class="fa fa-envelope"></span>   Newsletter</a></p>
# <h3 class="footer-contact-h3">
#           Connect with CSHL
#     </h3>
# <p class="social">
# <a href="http://www.facebook.com/cshlnews" title="like us on Facebook"><span class="fa fa-2x fa-facebook-square"></span></a>
#       <a href="http://twitter.com/cshl" title="follow us on Twitter"><img alt="twitter logo" src="../images/xtwitter_icon.png" style="margin-bottom: 14px;" title=""/></a>
#       <a href="http://instagram.com/cshlnews" title="view our photos on Instagram"><span class="fa fa-2x fa-instagram"></span></a>
#       <a href="http://www.youtube.com/ColdSpringHarborLab" title="visit CSHL on Youtube"><span class="fa fa-2x fa-youtube"></span></a>
#       <a href="https://www.linkedin.com/company/cold-spring-harbor-laboratory/" title="connect with CSHL on Linkedin"><span class="fa fa-2x fa-linkedin"></span></a>
#       <a href="https://flipboard.com/@CSHL" title="follow CSHL magazines on Flipboard"><span class="fa-stack"><span class="fa fa-square fa-stack-2x"><span class="fa-stack-1x flipboard">F</span></span></span></a>
#       <a href="/feed" title="CSHL RSS feed"><span class="fa fa-2x fa-rss"></span></a></p></div></div>
# </div>
# </div>
# </div> <!-- col -->
# </div> <!-- row -->
# <div class="row footer-copyright">
# <div class="col-sm-4 col-xs-12">
# <p class="small">© Copyright 2022 Cold Spring Harbor Laboratory. All Rights Reserved.</p>
# </div>
# <div class="col-sm-4 col-xs-12">
# <p class="small text-center">One Bungtown Road, Cold Spring Harbor, NY 11724</p>
# </div><!--col-->
# <div class="col-sm-4 col-xs-12">
# <p class="pull-right small"><a href="https://www.cshl.edu/about-us/sitemap/">Sitemap</a> | <a href="https://www.cshl.edu/about-us/privacy-policy/">Privacy Policy</a> <!--| <a href="#">Terms of Use</a>--> </p>
# </div>
# </div>
# </div>
# </footer>
# <!-- 3rd party JS files and scripts-->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js" type="text/javascript"></script>
# <script src="js/jquery.min.js"></script>
# <script src="js/jquery-2.2.4.js" type="text/javascript"></script>
# <script src="js/bootstrap.min.js" type="text/javascript"></script>
# <script src="js/megamenu.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.sticky/1.0.4/jquery.sticky.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/4.1.5/lazysizes.min.js"></script>
# <script>
#             // Search toggle.
#             $('.search-toggle').on('click.cshl-coresite', function (event) {
#                 event.preventDefault();
#                 var that = $(this),
#                     wrapper = $('#search-container'),
#                     container = that.find('a');
#
#                 that.toggleClass('active');
#                 wrapper.toggleClass('hide');
#
#                 if (that.hasClass('active')) {
#                     container.attr('aria-expanded', 'true');
#                     if ($(document).width() > 891) {// remove desktop hamburger menu
#                         $('.drawer-hamburger-icon').addClass('noTransition');
#                         $('.drawer-toggle.drawer-hamburger').addClass('noTransition');
#                         $('div.insite-nav').addClass('inVisible');
#                         $('.drawer-hamburger-icon').addClass('inVisible');
#                         $('.drawer-toggle.drawer-hamburger').addClass('inVisible');
#                     }
#                 } else {
#                     container.attr('aria-expanded', 'false');
#                     if ($(document).width() > 891) {// restore desktop hamburger menu
#                         $('.drawer-hamburger-icon').removeClass('noTransition');
#                         $('.drawer-toggle.drawer-hamburger').removeClass('noTransition');
#                         $('div.insite-nav').removeClass('inVisible');
#                         $('.drawer-hamburger-icon').removeClass('inVisible');
#                         $('.drawer-toggle.drawer-hamburger').removeClass('inVisible');
#                     }
#                 }
#                 if (that.is('.active') || $('.search-toggle .screen-reader-text')[0] === event.target) {
#                     wrapper.find('.search-field').focus();
#                 }
#             });
#         </script>
# <script src="https://cdn.jsdelivr.net/jquery.jssocials/1.4.0/jssocials.min.js" type="text/javascript"></script>
# <script>
#             $("#share").jsSocials({
#                 shares: ["email", "twitter", "facebook", "googleplus"]
#             });
#         </script>
# <script type="text/javascript">
#             $('.mtitle16').replaceWith("<h1 class='mtitle16' style='margin:10px 0 10px 0'>" + $('.mtitle16').html() + "</h1>");
#         </script>
# <script type="text/javascript">
#             //full screen overlay toggle
#             $("#home-toggle").click(function () {
#                 //toggle classes on overlay
#                 $(this).toggleClass('active');
#                 $("#overlay").toggleClass('open');
#             });
#
#             $("#close-overlay-toggle").click(function () {
#                 // toggle classes on overlay
#                 $(this).toggleClass('active');
#                 $("#overlay").toggleClass('open');
#             });
#         </script>
# <script type="text/javascript">
#             //$(function () {
#             //    $("body").prognroll({
#             //        height: 5,
#             //        color: "#005190", //Progress bar background color
#             //        custom: false //If you make it true, you can add your custom div and see it's scroll progress on the page
#             //    });
#             //});
#
#         </script>
# <script>
#             //var classes = ['left', 'center', 'right'];
#             $(document).ready(function () {
#                 $("#sticker").sticky({ topSpacing: 0, zIndex: 999999 });
#                 $('#sticker').on('sticky-update', function () { console.log("Update"); });
#
#             });
#         </script>
# <link href="css/footablelocal.css" rel="stylesheet" type="text/css"/>
# <script src="Scripts/footablelocal.js" type="text/javascript"></script>
# <script type="text/javascript">
#             $(function () {
#                 $('#tblCustomers').footable();
#             });
#         </script>
# <script type="text/javascript">
#         $(".sci-type-btn").click(function (e) {
#             // Get the science type from the button
#             var selectSci = $(this).data("sort");
#             var selectColor;
#             switch(selectSci) {
#                 case 'C':
#                     // cancer
#                     selectColor = "rgba(85,172,238,.4)";
#                     break;
#                 case 'B':
#                     // cell biology
#                     selectColor = "rgba(46,204,113,.4)";
#                     break;
#                 case 'O':
#                     // omics
#                     selectColor = "rgba(230,126,34,.4)";
#                     break;
#                 case 'N':
#                     // neuroscience
#                     selectColor = "rgba(241,196,15,.4)"
#                     break;
#                 case 'G':
#                     // genetics
#                     selectColor = "rgba(176,148,112,.4)"
#                     break;
#                 case 'I':
#                     // immune
#                     selectColor = "rgba(179,0,0,.4)"
#                     break;
#                 default:
#                     selectColor = "white";
#                     break;
#             }
#             // Filter by science type
#             filter(selectSci, selectColor);
#
#             // Scroll to focus area on mobile
#             if (navigator.userAgent.match(/(iPod|iPhone|iPad|Android)/)) {
#                 $(window).scrollTo('.science-type-row', 150, {
#                     offset: -100
#                 });
#             }
#             e.preventDefault();
#         });
#
#         function filter(e, c) {
#             var regex = new RegExp(e);
#             // If data contains science type, change css to match science type
#             // otherwise leave default.
#             $('.science-type-row').css("background", "white").css("border-left", "4px solid white").filter(function () {
#                 regex.test($(this).data('sci'))
#                 return regex.test($(this).data('sci'))
#             }).css("background", c);
#         }
#         </script>
# <script>;(function(f){"use strict";"function"===typeof define&&define.amd?define(["jquery"],f):"undefined"!==typeof module&&module.exports?module.exports=f(require("jquery")):f(jQuery)})(function($){"use strict";function n(a){return!a.nodeName||-1!==$.inArray(a.nodeName.toLowerCase(),["iframe","#document","html","body"])}function h(a){return $.isFunction(a)||$.isPlainObject(a)?a:{top:a,left:a}}var p=$.scrollTo=function(a,d,b){return $(window).scrollTo(a,d,b)};p.defaults={axis:"xy",duration:0,limit:!0};$.fn.scrollTo=function(a,d,b){"object"=== typeof d&&(b=d,d=0);"function"===typeof b&&(b={onAfter:b});"max"===a&&(a=9E9);b=$.extend({},p.defaults,b);d=d||b.duration;var u=b.queue&&1<b.axis.length;u&&(d/=2);b.offset=h(b.offset);b.over=h(b.over);return this.each(function(){function k(a){var k=$.extend({},b,{queue:!0,duration:d,complete:a&&function(){a.call(q,e,b)}});r.animate(f,k)}if(null!==a){var l=n(this),q=l?this.contentWindow||window:this,r=$(q),e=a,f={},t;switch(typeof e){case "number":case "string":if(/^([+-]=?)?\d+(\.\d+)?(px|%)?$/.test(e)){e= h(e);break}e=l?$(e):$(e,q);case "object":if(e.length===0)return;if(e.is||e.style)t=(e=$(e)).offset()}var v=$.isFunction(b.offset)&&b.offset(q,e)||b.offset;$.each(b.axis.split(""),function(a,c){var d="x"===c?"Left":"Top",m=d.toLowerCase(),g="scroll"+d,h=r[g](),n=p.max(q,c);t?(f[g]=t[m]+(l?0:h-r.offset()[m]),b.margin&&(f[g]-=parseInt(e.css("margin"+d),10)||0,f[g]-=parseInt(e.css("border"+d+"Width"),10)||0),f[g]+=v[m]||0,b.over[m]&&(f[g]+=e["x"===c?"width":"height"]()*b.over[m])):(d=e[m],f[g]=d.slice&& "%"===d.slice(-1)?parseFloat(d)/100*n:d);b.limit&&/^\d+$/.test(f[g])&&(f[g]=0>=f[g]?0:Math.min(f[g],n));!a&&1<b.axis.length&&(h===f[g]?f={}:u&&(k(b.onAfterFirst),f={}))});k(b.onAfter)}})};p.max=function(a,d){var b="x"===d?"Width":"Height",h="scroll"+b;if(!n(a))return a[h]-$(a)[b.toLowerCase()]();var b="client"+b,k=a.ownerDocument||a.document,l=k.documentElement,k=k.body;return Math.max(l[h],k[h])-Math.min(l[b],k[b])};$.Tween.propHooks.scrollLeft=$.Tween.propHooks.scrollTop={get:function(a){return $(a.elem)[a.prop]()}, set:function(a){var d=this.get(a);if(a.options.interrupt&&a._last&&a._last!==d)return $(a.elem).stop();var b=Math.round(a.now);d!==b&&($(a.elem)[a.prop](b),a._last=this.get(a))}};return p});</script>
# </form>
# </body>
# </html>

# %% [markdown]
# Well, that's better formatted, but still a lot of content to go through. How can we break this up?

# %% [markdown]
# ### Soup components

# %% [markdown]
# We can use Beautiful Soup to review different parts of the response separately as _tags_, e.g.:
# - title
# - head
# - body

# %%
cshl_meetings_soup.title
# Out:
# <title>
# 	Meetings on Cancer, Cells, Genomics, Neuroscience, Genetics and Immunology
# </title>

# %% [raw]
# cshl_meetings_soup.body

# %% [markdown]
# Hrm. We know from the course site that "Network Biology" is one of the courses we expect. Let's search for that.

# %%
table = cshl_meetings_soup.find(id='tblCustomers')
table_rows = table.find_all("tr")

# %%
len(table_rows)
# Out:
# 28

# %%
table_rows[1].find_all('td')[0].a.text
# Out:
# 'Neurodegenerative Diseases: Biology & Therapeutics'

# %%
table_rows[1].find_all('td')[1].text.strip()
# Out:
# 'Wed Dec 4 - Sat Dec 7 2024'

# %%
table_rows[1].find_all('td')[2].text.strip()
# Out:
# 'Fri Sep 13 2024'

# %%
course_info = dict()
for row in table_rows[1:]:
    row_data = row.find_all('td')
    course_info[row_data[0].a.text] = [
        row.find_all('td')[1].text.strip(),
        row.find_all('td')[2].text.strip()
    ]
course_info
# Out:
# {'Neurodegenerative Diseases: Biology & Therapeutics': ['Wed Dec 4 - Sat Dec 7 2024',
#   'Fri Sep 13 2024'],
#  'Development & 3D Modeling of the Human Brain': ['Mon Dec 9 - Thu Dec 12 2024',
#   'Mon Oct 7 2024'],
#  'Probabilistic Modeling in Genomics': ['Wed Mar 5 - Sat Mar 8 2025',
#   'Fri Jan 10 2025'],
#  'Network Biology': ['Tue Mar 11 - Sat Mar 15 2025', 'Fri Jan 10 2025'],
#  'Nucleic Acid Therapies': ['Wed Mar 19 - Sat Mar 22 2025', 'Fri Jan 17 2025'],
#  'Cancer Genetics: History & Consequences': ['Wed Mar 26 - Sat Mar 29 2025',
#   'Fri Jan 31 2025'],
#  'Ubiquitins, Autophagy & Disease': ['Tue Apr 1 - Sat Apr 5 2025',
#   'Fri Jan 17 2025'],
#  'Brain Barriers': ['Tue Apr 8 - Sat Apr 12 2025', 'Fri Jan 24 2025'],
#  'Systems Immunology': ['Tue Apr 22 - Sat Apr 26 2025', 'Fri Jan 31 2025'],
#  'Telomeres & Telomerase': ['Tue Apr 29 - Sat May 3 2025', 'Fri Feb 7 2025'],
#  'Biology of Genomes': ['Tue May 6 - Sat May 10 2025', 'Fri Feb 14 2025'],
#  'Mechanisms of Metabolic Signaling': ['Tue May 13 - Sat May 17 2025',
#   'Fri Feb 21 2025'],
#  'Retroviruses': ['Mon May 19 - Sat May 24 2025', 'Fri Feb 28 2025'],
#  '89th Symposium: Senescence & Aging': ['Wed May 28 - Sun Jun 1 2025',
#   'Fri Mar 7 2025'],
#  'Advances in Brain Tumor Research & Therapy': ['Thu Jul 17 - Sun Jul 20 2025',
#   'Fri Apr 25 2025'],
#  'Genome Engineering: CRISPR Frontiers': ['Tue Aug 12 - Sat Aug 16 2025',
#   'Fri May 23 2025'],
#  'Eukaryotic mRNA Processing': ['Tue Aug 19 - Sat Aug 23 2025',
#   'Fri May 30 2025'],
#  'Mechanisms of Eukaryotic Transcription': ['Tue Aug 26 - Sat Aug 30 2025',
#   'Fri Jun 6 2025'],
#  'Eukaryotic DNA Replication & Genome Maintenance': ['Tue Sep 2 - Sat Sep 6 2025',
#   'Fri Jun 13 2025'],
#  'Microbial Pathogenesis & Host Response': ['Mon Sep 8 - Fri Sep 12 2025',
#   'Fri Jun 20 2025'],
#  'Biology of Cancer: Microenvironment & Metastasis': ['Tue Sep 16 - Sat Sep 20 2025',
#   'Fri Jun 27 2025'],
#  'Cell Fate Conversions': ['Wed Sep 24 - Sat Sep 27 2025', 'Mon Jul 7 2025'],
#  'Neurobiology of Drosophila': ['Tue Oct 7 - Sat Oct 11 2025',
#   'Mon Jul 21 2025'],
#  'Genome Informatics': ['Wed Nov 5 - Sat Nov 8 2025', 'Fri Aug 22 2025'],
#  'Single Cell Analyses': ['Wed Nov 12 - Sat Nov 15 2025', 'Fri Aug 29 2025'],
#  'Zebrafish Neurobiology': ['Wed Nov 19 - Sat Nov 22 2025', 'Fri Sep 5 2025'],
#  'Plant Genomes, Systems Biology & Engineering': ['Wed Dec 3 - Sat Dec 6 2025',
#   'Fri Sep 12 2025']}
